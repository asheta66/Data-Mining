# %% [markdown]
# <a href="https://colab.research.google.com/github/asheta66/Data-Mining/blob/main/Executing_Feature_Selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone GitHub repository

# !git clone https://github.com/wesalmagdi/Feature-Selection-Using-Metaheuristic-Approaches.git

# %cd Feature-Selection-Using-Metaheuristic-Approaches
# Out:
# fatal: destination path 'Feature-Selection-Using-Metaheuristic-Approaches' already exists and is not an empty directory.
# /content/Feature-Selection-Using-Metaheuristic-Approaches

# %%
# Install required packages

# !pip install -r requirements.txt

# %%
import os

print(os.getcwd())

for item in os.listdir():
    print(item)
# Out:
# /content/Feature-Selection-Using-Metaheuristic-Approaches
# utils
# results
# .git
# gitignore
# requirements.txt
# datasets
# README.md
# executed
# notebooks

# %%
# %cd executed/final

# !ls
# Out:
# /content/Feature-Selection-Using-Metaheuristic-Approaches/executed/final
# 01_Data_Preprocessing.executed.ipynb	05_GWO_FS.executed.ipynb
# 02_Baseline_Classifier.executed.ipynb	06_WOA_FS.executed.ipynb
# 03_Genetic_Algorithm_FS.executed.ipynb	07_Crow_Search_FS.executed.ipynb
# 04_PSO_FS.executed.ipynb		08_Comparison.executed.ipynb

# %%
# !pip install nbconvert

# %%
# %cd ../..
# Out:
# /content/Feature-Selection-Using-Metaheuristic-Approaches

# %%
# !jupyter nbconvert \
--to notebook \
--execute executed/final/01_Data_Preprocessing.executed.ipynb \
--output executed/final/01_Data_Preprocessing.executed_run.ipynb
# Out:
# [NbConvertApp] Converting notebook executed/final/01_Data_Preprocessing.executed.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Traceback (most recent call last):
#   File "/usr/local/bin/jupyter-nbconvert", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/jupyter_core/application.py", line 284, in launch_instance
# ...

# %%
# !jupyter nbconvert \
--to notebook \
--execute executed/final/02_Baseline_Classifier.executed.ipynb \
--output executed/final/02_Baseline_Classifier.executed_run.ipynb
# Out:
# [NbConvertApp] Converting notebook executed/final/02_Baseline_Classifier.executed.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Traceback (most recent call last):
#   File "/usr/local/bin/jupyter-nbconvert", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/jupyter_core/application.py", line 284, in launch_instance
# ...

# %%
# !jupyter nbconvert \
--to notebook \
--execute executed/final/03_Genetic_Algorithm_FS.executed.ipynb \
--output executed/final/03_GA_run.ipynb
# Out:
# [NbConvertApp] Converting notebook executed/final/03_Genetic_Algorithm_FS.executed.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Traceback (most recent call last):
#   File "/usr/local/bin/jupyter-nbconvert", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/jupyter_core/application.py", line 284, in launch_instance
# ...

# %%
# !jupyter nbconvert \
--to notebook \
--execute notebooks/00_Kaggle_Run_All.ipynb \
--output Full_Run_Result.ipynb
# Out:
# [NbConvertApp] Converting notebook notebooks/00_Kaggle_Run_All.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Traceback (most recent call last):
#   File "/usr/local/bin/jupyter-nbconvert", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/jupyter_core/application.py", line 284, in launch_instance
# ...

# %%
# %cd results/final
# Out:
# /content/Feature-Selection-Using-Metaheuristic-Approaches/results/final

# %%
import pandas as pd

results = pd.read_csv("comparison_summary.csv")

results
# Out:
#    Dataset     Classifier Algorithm  Runs  AccuracyMean  AccuracyStd  \
# 0   breast  random_forest  Baseline     1      0.973684          NaN
# 1   breast  random_forest       CSA     5      0.942105     0.014678
# 2   breast  random_forest        GA     5      0.957895     0.026607
# 3   breast  random_forest       GWO     5      0.957895     0.027320
# 4   breast  random_forest       PSO     5      0.952632     0.015935
# 5   breast  random_forest       WOA     5      0.966667     0.021842
# 6   breast            svm  Baseline     1      0.982456          NaN
# 7   breast            svm       CSA     5      0.963158     0.014414
# 8   breast            svm        GA     5      0.970175     0.010002
# 9   breast            svm       GWO     5      0.971930     0.009609
# 10  breast            svm       PSO     5      0.978947     0.004805
# 11  breast            svm       WOA     5      0.971930     0.007339
# 12  breast        xgboost  Baseline     1      0.973684          NaN
# ...

# %%
from IPython.display import Image, display
import os

plot_path="plots"

for img in os.listdir(plot_path):
    if img.endswith(".png"):
        display(Image(filename=f"{plot_path}/{img}"))
